# %%
print("hello world")
# Out:
# hello world

# %%
import pandas as  pd

# %%
df = pd.read_excel("BalanceGeneral2015SIREMV2.xls")

# %%
df.head()  # DIEGO UTILICE REGULAR EXPRESSIONS DEL MODULO IMPORT RE
# Out:
#          NIT                                       RAZON SOCIAL  \
# 0  800000001                  AGROINDUSTRIA EL TRIUNFO LIMITADA
# 1  800000090  INGENIEROS SERVICIOS CONSTRUCTIVOS S.A.       ...
# 2  800000251                    INGENIERIA Y DISEÃ‘O I E P LTDA
# 3  800000268                        DISEÃ‘O DE INTERIORES S A S
# 4  800000276                            AVICOLA EL MADROÃ‘O S A
#
#                       CIUDAD               DEPARTAMENTO  \
# 0  VILLAVICENCIO              META
# 1  MEDELLIN                   ANTIOQUIA
# 2              BOGOTA D.C.                  BOGOTA D.C.
# 3  BARRANQUILLA               ATLANTICO
# 4  BUCARAMANGA                SANTANDER
#
#            DIRECCION DE DOMICILIO   CIIU  \
# 0                  CALLE 15 16 41  A0111
# 1                    CL 8 B 30 73  F4111
# 2     CRA 67 NO. 167 - 61 OF. 519  C1101
# 3               CARRERA 53 82 115  L6810
# 4  KM 6 VIA GIRON CRA 12 N. 57-88  A0145
#
# ...
